# %% [markdown]
# # Chicago Road Network

# %% [markdown]
# ## Preprocessing

# %%
import networkx as nx
import numpy as np
import pandas as pd

# %%
path = 'Chicago_RoadNetwork/edges.csv'

edge_list = pd.read_csv(path)
print(edge_list.columns)
# Out:
# Index(['source', 'target'], dtype='object')

# %%
edges = list(edge_list.itertuples(index=False, name=None))

G = nx.DiGraph()
G.add_edges_from(edges)

print('Number of edges: ', G.number_of_edges())
print('Number of nodes: ', G.number_of_nodes())
# Out:
# Number of edges:  39018
# Number of nodes:  12979

# %% [markdown]
# ## Strategies

# %% [markdown]
# The following section will shows the implementation of the different pivot selection strategies. We applied 5 different strategies:
#
# 1. Random
# The random strategy selects nodes at random.
#
# 2. Random indegree
# The random indegree strategy selects pivots with a probability proportional to their indegree
#
# 3. Random outdegree
# The random outdegree strategy selects pivots with a probability proportional to their outdegree
#
# 4. Page rank based selection
# The page rank based selection strategy select pivtos accoring to their page rank.
#
# 5. Mixed Strategy
# The mixed strategy iterates through all startegies to select the pivots

# %%
def random_strategy(G, num_pivots):

    return np.random.choice(list(G.nodes), size=num_pivots, replace=False)

# %%
# Function for random selection based on in-degree
def ran_indeg_strategy(G, num_pivots):
    # Get the in-degree of each node
    indegrees = dict(G.in_degree())
    all_nodes = list(G.nodes)
    
    # Create a list of probabilities proportional to node in-degrees
    degree_sum = sum(indegrees.values())
    probabilities = [indegrees[node] / degree_sum for node in all_nodes]
    
    # Randomly select pivots with probability proportional to their in-degree
    pivots = np.random.choice(all_nodes, size=num_pivots, replace=False, p=probabilities)
    
    return pivots

# %%
# Function for random selection based on out-degree
def ran_outdeg_strategy(G, num_pivots):
    # Get the out-degree of each node
    outdegrees = dict(G.out_degree())
    all_nodes = list(G.nodes)
    
    # Create a list of probabilities proportional to node out-degrees
    degree_sum = sum(outdegrees.values())
    probabilities = [outdegrees[node] / degree_sum for node in all_nodes]
    
    # Randomly select pivots with probability proportional to their out-degree
    pivots = np.random.choice(all_nodes, size=num_pivots, replace=False, p=probabilities)
    
    return pivots

# %%
def pagerank_pivot_selection(G, num_pivots):
    """
    Select pivots based on PageRank scores.
    
    Parameters:
    - G: NetworkX directed graph (DiGraph)
    - num_pivots: Number of pivots to select
    
    Returns:
    - List of pivot nodes
    """
    # Calculate PageRank scores
    pagerank_scores = nx.pagerank(G)
    
    # Sort nodes by PageRank scores in descending order
    sorted_nodes = sorted(pagerank_scores, key=pagerank_scores.get, reverse=True)
    
    # Select the top nodes as pivots
    pivots = sorted_nodes[:num_pivots]
    return pivots

# %%
def mixed_strategy(G, num_pivots):

    strategies = [random_strategy, ran_indeg_strategy, 
              ran_outdeg_strategy, pagerank_pivot_selection]

    selected_pivots = set()
    strategy_count = len(strategies)
    
    strategy_iter = iter(strategies)
    
    while len(selected_pivots) < num_pivots:
        try:
            strategy = next(strategy_iter)
        except StopIteration:
            strategy_iter = iter(strategies)
            strategy = next(strategy_iter)

        remaining_pivots = num_pivots - len(selected_pivots)
        candidates = strategy(G, remaining_pivots)
        
        for pivot in candidates:
            if len(selected_pivots) < num_pivots:
                selected_pivots.add(pivot)
            else:
                break

    return list(selected_pivots)

# %%
pivots = mixed_strategy(G, 1000)
pivots
# Out:
# [2,
#  6148,
#  8198,
#  2054,
#  9,
#  10249,
#  8206,
#  8207,
#  8211,
#  8212,
#  20,
#  22,
#  21,
#  12311,
#  2072,
#  2074,
#  8219,
#  10268,
#  8222,
#  2080,
#  12323,
#  6182,
#  4136,
#  10281,
#  6189,
#  4144,
#  10291,
#  6196,
#  51,
#  12342,
#  4151,
#  8247,
#  4152,
#  12351,
#  67,
#  68,
#  79,
#  4179,
#  10324,
#  12374,
#  8280,
#  2139,
#  4191,
#  12385,
#  8291,
#  2147,
#  8292,
#  8294,
#  2152,
#  12394,
#  12396,
#  8303,
#  119,
#  10361,
#  8315,
#  10363,
#  4224,
#  4228,
#  2183,
#  12424,
#  137,
#  12427,
#  4236,
#  6286,
#  4239,
#  6290,
#  2195,
#  4249,
#  12443,
#  156,
#  8349,
#  4252,
#  2207,
#  6304,
#  12450,
#  2213,
#  6310,
#  12455,
#  8360,
#  12456,
#  12458,
#  2219,
#  10412,
#  172,
#  6318,
#  8367,
#  10411,
#  2225,
#  4267,
#  181,
#  4278,
#  8377,
#  4283,
#  2236,
#  6331,
#  4287,
#  10431,
#  8385,
#  191,
#  4291,
#  10434,
#  10438,
#  199,
#  8392,
#  10441,
#  4297,
#  8393,
#  12492,
#  2253,
#  12495,
#  6351,
#  2258,
#  6357,
#  8405,
#  10455,
#  8411,
#  220,
#  8413,
#  8415,
#  225,
#  8418,
#  2281,
#  2282,
#  4330,
#  2284,
#  6380,
#  12521,
#  6384,
#  10483,
#  8438,
#  4346,
#  8444,
#  6397,
#  254,
#  2305,
#  257,
#  8455,
#  4361,
#  12555,
#  270,
#  12559,
#  2322,
#  4371,
#  276,
#  10516,
#  8470,
#  6423,
#  8471,
#  10519,
#  10522,
#  10526,
#  2338,
#  4386,
#  6434,
#  2341,
#  8495,
#  12592,
#  12597,
#  2358,
#  6455,
#  6454,
#  8610,
#  6458,
#  6459,
#  10557,
#  10561,
#  4420,
#  12613,
#  4421,
#  326,
#  328,
#  12617,
#  10570,
#  6476,
#  4428,
#  8528,
#  341,
#  8535,
#  6487,
#  6489,
#  10589,
#  10590,
#  12639,
#  352,
#  2403,
#  2404,
#  2405,
#  6502,
#  4455,
#  2409,
#  361,
#  10603,
#  4466,
#  8562,
#  12662,
#  4470,
#  10614,
#  10658,
#  12669,
#  6527,
#  385,
#  387,
#  388,
#  8580,
#  8582,
#  10628,
#  8586,
#  2446,
#  8590,
#  6543,
#  8596,
#  6549,
#  12695,
#  12696,
#  12698,
#  12701,
#  8609,
#  4514,
#  6563,
#  420,
#  4516,
#  2470,
#  12708,
#  6568,
#  12712,
#  8618,
#  4523,
#  10668,
#  4522,
#  10667,
#  6569,
#  435,
#  10675,
#  4533,
#  10680,
#  4537,
#  6586,
#  4540,
#  6589,
#  12736,
#  12741,
#  2501,
#  1490,
#  11730,
#  11734,
#  9686,
#  1498,
#  3547,
#  11741,
#  7646,
#  7648,
#  1505,
#  7661,
#  5616,
#  3569,
#  9714,
#  7669,
#  1528,
#  7686,
#  1542,
#  9736,
#  3593,
#  11789,
#  7695,
#  5651,
#  11797,
#  3606,
#  1560,
#  7704,
#  11802,
#  11810,
#  7715,
#  5672,
#  9771,
#  11823,
#  11824,
#  9776,
#  9775,
#  9781,
#  11829,
#  11831,
#  3637,
#  9785,
#  5690,
#  5691,
#  5693,
#  5694,
#  7743,
#  7746,
#  7749,
#  11845,
#  5703,
#  7752,
#  3660,
#  11853,
#  1612,
#  5710,
#  3668,
#  9817,
#  1626,
#  1627,
#  9818,
#  11869,
#  5725,
#  1629,
#  9826,
#  11875,
#  3684,
#  1639,
#  7784,
#  3692,
#  5741,
#  7790,
#  11888,
#  7792,
#  5745,
#  11891,
#  1650,
#  3701,
#  3698,
#  1649,
#  7796,
#  1667,
#  3716,
#  11911,
#  7817,
#  5775,
#  9873,
#  11922,
#  5780,
#  1685,
#  5782,
#  9881,
#  1693,
#  3743,
#  7841,
#  7842,
#  5794,
#  9897,
#  5802,
#  9901,
#  11949,
#  11951,
#  9906,
#  7860,
#  9910,
#  9912,
#  11965,
#  9921,
#  11970,
#  11976,
#  5832,
#  11985,
#  3800,
#  3801,
#  9947,
#  3803,
#  1757,
#  1759,
#  3807,
#  7905,
#  1762,
#  3811,
#  9958,
#  12008,
#  1768,
#  7914,
#  3818,
#  12010,
#  3821,
#  7917,
#  3823,
#  7913,
#  7921,
#  12021,
#  7926,
#  7927,
#  7930,
#  1790,
#  12032,
#  12033,
#  12034,
#  7938,
#  1800,
#  9993,
#  1802,
#  5904,
#  1811,
#  1812,
#  7956,
#  7955,
#  3864,
#  12056,
#  12058,
#  1819,
#  3868,
#  1823,
#  3874,
#  10021,
#  1832,
#  7979,
#  5934,
#  3887,
#  12080,
#  10030,
#  7988,
#  10038,
#  1847,
#  10040,
#  1848,
#  3896,
#  5942,
#  12093,
#  1857,
#  10050,
#  10051,
#  3908,
#  3910,
#  8007,
#  12104,
#  5961,
#  5962,
#  10064,
#  12113,
#  1875,
#  1876,
#  12119,
#  12122,
#  8026,
#  10080,
#  10082,
#  1895,
#  10092,
#  3958,
#  1914,
#  12154,
#  12165,
#  1927,
#  6025,
#  10125,
#  6032,
#  8082,
#  8084,
#  8091,
#  8092,
#  3996,
#  4003,
#  8099,
#  4005,
#  8105,
#  6057,
#  1963,
#  6061,
#  1965,
#  8111,
#  6064,
#  8113,
#  1971,
#  10166,
#  12215,
#  12220,
#  4028,
#  12222,
#  10173,
#  6080,
#  4033,
#  4030,
#  10178,
#  4038,
#  10183,
#  10182,
#  8144,
#  8145,
#  2005,
#  6102,
#  12247,
#  8151,
#  2010,
#  2016,
#  2021,
#  10218,
#  10219,
#  8170,
#  4084,
#  6139,
#  2046]

# %% [markdown]
# ## Metrics

# %%
def euclidean_distance(exact, estimated):
    """
    Compute the normalized Euclidean distance between two centrality dictionaries.
    
    Parameters:
    - exact: dict, exact centrality values
    - estimated: dict, estimated centrality values
    
    Returns:
    - float, the normalized Euclidean distance
    """
    exact_values = np.array([exact[node] for node in exact])
    estimated_values = np.array([estimated[node] for node in exact])  # Ensure consistent order
    
    # Compute the Euclidean distance
    raw_distance = np.linalg.norm(exact_values - estimated_values)
    
    # Normalize by the magnitude of the exact centrality values
    normalization_factor = np.linalg.norm(exact_values)
    if normalization_factor == 0:  # Handle edge case where exact values are all zeros
        return 0.0
    
    return raw_distance / normalization_factor

# %%
from itertools import combinations

def compute_inversion_distance(exact_scores, estimated_scores):
    # Rank the nodes based on scores (higher scores get lower ranks)
    exact_ranking = sorted(exact_scores.items(), key=lambda x: x[1], reverse=True)
    estimated_ranking = sorted(estimated_scores.items(), key=lambda x: x[1], reverse=True)

    # Create dictionaries to map nodes to their ranks
    exact_ranks = {node: rank for rank, (node, _) in enumerate(exact_ranking, 1)}
    estimated_ranks = {node: rank for rank, (node, _) in enumerate(estimated_ranking, 1)}

    # Count inversions
    inversion_count = 0
    for u, v in combinations(exact_scores.keys(), 2):  # Compare all pairs of nodes
        exact_order = exact_ranks[u] - exact_ranks[v]  # Positive if u ranks higher than v
        estimated_order = estimated_ranks[u] - estimated_ranks[v]  # Positive if u ranks higher than v
        
        if exact_order * estimated_order < 0:  # Orders are inverted
            inversion_count += 1

    return inversion_count

# %%
exact_closeness = nx.closeness_centrality(G)
exact_betweenness = nx.betweenness_centrality(G)

print(exact_closeness)
print(exact_betweenness)

# %%
all_shortest_paths = dict(nx.all_pairs_all_shortest_paths(G))
print(all_shortest_paths[0][2])

# %%
print(all_shortest_paths[0][0][0])
# Out:
# [0]

# %% [markdown]
# ## Closeness Centrality

# %% [markdown]
# 1. Select pivots according to the pivot selection strategies
# 2. Compute distance from pivot to all other nodes in G (d(pivot, node)) for out-closeness centrality.
# 3. Calculate the sum of all shortest paths
# 4. Devide the number of pivots by the sum from step 3

# %%
pivots = G.nodes
approximated_closeness = {}
for pivot in pivots:
    num_reachable_nodes = 0
    distances = 0
    for node in G.nodes:
        if node in all_shortest_paths and pivot in all_shortest_paths[node]:
            d = len(all_shortest_paths[node][pivot][0]) - 1  # Subtract 1 to get the number of edges
            if d > 0:  # Ensure the distance is valid
                distances += d
                num_reachable_nodes += 1
    if distances > 0:  # Prevent division by zero
        approximated_closeness[pivot] = num_reachable_nodes / distances
    else:
        approximated_closeness[pivot] = 0  # Assign 0 or another default value when no distances are found

print(approximated_closeness)
# Out:
# {0: 0.32142857142857145, 1: 0.2975871313672922, 2: 0.3126760563380282, 3: 0.30027051397655546, 4: 0.30117576123002715, 5: 0.27905027932960896, 6: 0.2859187178019462, 7: 0.2942562592047128, 8: 0.2862464183381089, 9: 0.32184278350515466, 10: 0.3234056328909032, 11: 0.31044126786824117, 12: 0.3163394553514883, 13: 0.29460336184016517, 14: 0.30587875076546234, 15: 0.28014582164890633, 16: 0.3171428571428571, 17: 0.3263639333551127, 18: 0.
.29723296637905383, 137: 0.34083930399181167, 138: 0.2905759162303665, 139: 0.3208092485549133, 140: 0.31978233034571063, 141: 0.2960877296976882, 142: 0.333, 143: 0.29838709677419356, 144: 0.31111803176580505, 145: 0.3047589993898719, 146: 0.3233009708737864, 147: 0.30383211678832117, 148: 0.3039245512625494, 149: 0.29838709677419356, 150: 0.3159392789373814, 151: 0.2981199641897941, 152: 0.31277395115842205, 153: 0.313953488372093, 154: 0.32008971483498877, 155: 0.3236151603498542, 156: 0.29910179640718565, 157: 0.3034629404617254, 158: 0.24844566028351156, 159: 0.29133858267716534, 160: 0.32414016872160933, 161: 0.3031866464339909, 162: 0.2994604316546763, 163:  ...

# %%
def run_strategy(G, strategy, num_pivots, all_shortest_paths):
    pivots = strategy(G, num_pivots)
    approximated_closeness = {}
    
    for node in G.nodes:
        num_reachable_nodes = 0
        distances = 0
        
        for pivot in pivots:
            if pivot in all_shortest_paths and node in all_shortest_paths[pivot]:
                d = len(all_shortest_paths[pivot][node][0]) - 1 
                if d > 0:  
                    distances += d
                    num_reachable_nodes += 1
        if distances > 0:
            approximated_closeness[node] = num_reachable_nodes / distances
        else:
            approximated_closeness[node] = 0 
    
    return approximated_closeness

# %%
random = run_strategy(G, random_strategy, 1000, all_shortest_paths)
indeg = run_strategy(G, ran_indeg_strategy, 1000, all_shortest_paths)
outdeg= run_strategy(G, ran_outdeg_strategy, 1000, all_shortest_paths)
pr = run_strategy(G, pagerank_pivot_selection, 10, all_shortest_paths)

pr
# Out:
# {0: 0.3225806451612903,
#  1: 0.30303030303030304,
#  2: 0.30303030303030304,
#  3: 0.3225806451612903,
#  4: 0.30303030303030304,
#  5: 0.29411764705882354,
#  6: 0.29411764705882354,
#  7: 0.30303030303030304,
#  8: 0.2631578947368421,
#  9: 0.3125,
#  10: 0.37037037037037035,
#  11: 0.2857142857142857,
#  12: 0.3125,
#  13: 0.2857142857142857,
#  14: 0.29411764705882354,
#  15: 0.2702702702702703,
#  16: 0.35714285714285715,
#  17: 0.35714285714285715,
#  18: 0.3225806451612903,
#  19: 0.3333333333333333,
#  20: 0.3225806451612903,
#  21: 0.2857142857142857,
#  22: 0.4166666666666667,
#  23: 0.3448275862068966,
#  24: 0.29411764705882354,
#  25: 0.3125,
#  26: 0.30303030303030304,
#  27: 0.3225806451612903,
#  28: 0.3333333333333333,
#  29: 0.2857142857142857,
#  30: 0.30303030303030304,
#  31: 0.2857142857142857,
#  32: 0.30303030303030304,
#  33: 0.3125,
#  34: 0.3125,
#  35: 0.37037037037037035,
#  36: 0.3225806451612903,
#  37: 0.29411764705882354,
#  38: 0.2857142857142857,
#  39: 0.29411764705882354,
#  40: 0.3125,
#  41: 0.35714285714285715,
#  42: 0.2857142857142857,
#  43: 0.30303030303030304,
#  44: 0.2702702702702703,
#  45: 0.3125,
#  46: 0.3333333333333333,
#  47: 0.2702702702702703,
#  48: 0.29411764705882354,
#  49: 0.30303030303030304,
#  50: 0.30303030303030304,
#  51: 0.3125,
#  901: 0.3333333333333333,
#  902: 0.3125,
#  903: 0.2857142857142857,
#  904: 0.3448275862068966,
#  905: 0.29411764705882354,
#  906: 0.3333333333333333,
#  907: 0.3448275862068966,
#  908: 0.3125,
#  909: 0.3225806451612903,
#  910: 0.3225806451612903,
#  911: 0.3225806451612903,
#  912: 0.2857142857142857,
#  913: 0.2702702702702703,
#  914: 0.3448275862068966,
#  915: 0.3448275862068966,
#  916: 0.3125,
#  917: 0.3225806451612903,
#  918: 0.2777777777777778,
#  919: 0.2857142857142857,
#  920: 0.25,
#  921: 0.2564102564102564,
#  922: 0.29411764705882354,
#  923: 0.35714285714285715,
#  924: 0.29411764705882354,
#  925: 0.29411764705882354,
#  926: 0.2857142857142857,
#  927: 0.3125,
#  928: 0.2857142857142857,
#  929: 0.29411764705882354,
#  930: 0.3333333333333333,
#  931: 0.29411764705882354,
#  932: 0.30303030303030304,
#  933: 0.3333333333333333,
#  934: 0.3125,
#  935: 0.30303030303030304,
#  936: 0.3125,
#  937: 0.2777777777777778,
#  938: 0.3225806451612903,
#  939: 0.3125,
#  940: 0.3125,
#  941: 0.3333333333333333,
#  942: 0.2857142857142857,
#  943: 0.2702702702702703,
#  944: 0.3225806451612903,
#  945: 0.29411764705882354,
#  946: 0.30303030303030304,
#  947: 0.2857142857142857,
#  948: 0.3448275862068966,
#  949: 0.3333333333333333,
#  950: 0.3125,
#  951: 0.2702702702702703,
#  952: 0.3333333333333333,
#  953: 0.2777777777777778,
#  954: 0.35714285714285715,
#  955: 0.3333333333333333,
#  956: 0.3448275862068966,
#  957: 0.2857142857142857,
#  958: 0.3448275862068966,
#  959: 0.38461538461538464,
#  960: 0.36,
#  961: 0.3448275862068966,
#  962: 0.2702702702702703,
#  963: 0.3125,
#  964: 0.30303030303030304,
#  965: 0.2702702702702703,
#  966: 0.3125,
#  967: 0.30303030303030304,
#  968: 0.30303030303030304,
#  969: 0.29411764705882354,
#  970: 0.2857142857142857,
#  971: 0.3333333333333333,
#  972: 0.3225806451612903,
#  973: 0.29411764705882354,
#  974: 0.29411764705882354,
#  975: 0.3125,
#  976: 0.2857142857142857,
#  977: 0.3448275862068966,
#  978: 0.35714285714285715,
#  979: 0.2857142857142857,
#  980: 0.29411764705882354,
#  981: 0.3225806451612903,
#  982: 0.30303030303030304,
#  983: 0.2857142857142857,
#  984: 0.29411764705882354,
#  985: 0.2857142857142857,
#  986: 0.3448275862068966,
#  987: 0.29411764705882354,
#  988: 0.3225806451612903,
#  989: 0.35714285714285715,
#  990: 0.2857142857142857,
#  991: 0.3125,
#  992: 0.3225806451612903,
#  993: 0.2857142857142857,
#  994: 0.30303030303030304,
#  995: 0.30303030303030304,
#  996: 0.29411764705882354,
#  997: 0.29411764705882354,
#  998: 0.29411764705882354,
#  999: 0.29411764705882354}

# %%
strategies = [random_strategy, ran_indeg_strategy, 
              ran_outdeg_strategy, pagerank_pivot_selection, mixed_strategy]

num_pivots_list = [int(len(G.nodes) / 20 * i) for i in range(1, 21)]
print(num_pivots_list)
# Out:
# [50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700, 750, 800, 850, 900, 950, 1000]

# %%
from tqdm import tqdm 

from tqdm import tqdm
import numpy as np

def run_experiment(G, strategies, num_pivots_list, all_shortest_paths, exact_closeness, runs=20):
    results = {}

    for strategy in strategies:
        results[strategy.__name__] = {}
        for num_pivots in num_pivots_list:
            euclidean_distances = []
            inversions = []

            for _ in tqdm(range(runs), desc=f"Running {strategy.__name__} with {num_pivots} pivots"):
                # Run the strategy and calculate approximated closeness
                appr_closeness = run_strategy(G, strategy, num_pivots, all_shortest_paths)

                # Calculate metrics
                eucl_dist = euclidean_distance(exact_closeness, appr_closeness)
                inversion = compute_inversion_distance(exact_closeness, appr_closeness)

                # Collect results
                euclidean_distances.append(eucl_dist)
                inversions.append(inversion)

            # Store the average results
            avg_eucl_dist = np.mean(euclidean_distances)
            avg_inversion = np.mean(inversions)

            results[strategy.__name__][num_pivots] = {
                'average_euclidean_distance': avg_eucl_dist,
                'average_inversion_number': avg_inversion
            }

    return results



results = run_experiment(G, strategies, num_pivots_list, all_shortest_paths, exact_closeness)
# Out:
# Running random_strategy with 50 pivots: 100%|██████████| 20/20 [00:00<00:00, 21.64it/s]
# Running random_strategy with 100 pivots: 100%|██████████| 20/20 [00:01<00:00, 14.98it/s]
# Running random_strategy with 150 pivots: 100%|██████████| 20/20 [00:01<00:00, 13.35it/s]
# Running random_strategy with 200 pivots: 100%|██████████| 20/20 [00:01<00:00, 10.00it/s]
# Running random_strategy with 250 pivots: 100%|██████████| 20/20 [00:02<00:00,  8.56it/s]
# Running random_strategy with 300 pivots: 100%|██████████| 20/20 [00:02<00:00,  7.65it/s]
# Running random_strategy with 350 pivots: 100%|██████████| 20/20 [00:02<00:00,  7.07it/s]
# Running random_strategy with 400 pivots: 100%|██████████| 20/20 [00:02<00:00,  6.74it/s]
# Running random_strategy with 450 pivots: 100%|██████████| 20/20 [00:03<00:00,  5.92it/s]
# Running random_strategy with 500 pivots: 100%|██████████| 20/20 [00:03<00:00,  5.63it/s]
# Running random_strategy with 550 pivots: 100%|██████████| 20/20 [00:03<00:00,  5.13it/s]
# Running random_strategy with 600 pivots: 100%|██████████| 20/20 [00:04<00:00,  4.53it/s]
# Running random_strategy with 650 pivots: 100%|██████████| 20/20 [00:04<00:00,  4.35it/s]
# Running random_strategy with 700 pivots: 100%|██████████| 20/20 [00:04<00:00,  4.17it/s]
# Running random_strategy with 750 pivots: 100%|██████████| 20/20 [00:05<00:00,  3.62it/s]
# Running random_strategy with 800 pivots: 100%|██████████| 20/20 [00:06<00:00,  3.29it/s]
# Running random_strategy with 850 pivots: 100%|██████████| 20/20 [00:06<00:00,  3.15it/s]
# Running random_strategy with 900 pivots: 100%|██████████| 20/20 [00:06<00:00,  2.99it/s]
# Running random_strategy with 950 pivots: 100%|██████████| 20/20 [00:06<00:00,  2.86it/s]
# Running random_strategy with 1000 pivots: 100%|██████████| 20/20 [00:07<00:00,  2.73it/s]
# Running ran_indeg_strategy with 50 pivots: 100%|██████████| 20/20 [00:01<00:00, 18.46it/s]
# Running ran_indeg_strategy with 100 pivots: 100%|██████████| 20/20 [00:01<00:00, 14.53it/s]
# Running ran_indeg_strategy with 150 pivots: 100%|██████████| 20/20 [00:01<00:00, 12.03it/s]
# Running ran_indeg_strategy with 200 pivots: 100%|██████████| 20/20 [00:01<00:00, 10.14it/s]
# Running ran_indeg_strategy with 250 pivots: 100%|██████████| 20/20 [00:02<00:00,  9.18it/s]
# Running ran_indeg_strategy with 300 pivots: 100%|██████████| 20/20 [00:02<00:00,  7.66it/s]
# Running ran_indeg_strategy with 350 pivots: 100%|██████████| 20/20 [00:02<00:00,  6.93it/s]
# Running ran_indeg_strategy with 400 pivots: 100%|██████████| 20/20 [00:03<00:00,  6.05it/s]
# Running ran_indeg_strategy with 450 pivots: 100%|██████████| 20/20 [00:03<00:00,  5.37it/s]
# Running ran_indeg_strategy with 500 pivots: 100%|██████████| 20/20 [00:03<00:00,  5.28it/s]
# Running ran_indeg_strategy with 550 pivots: 100%|██████████| 20/20 [00:04<00:00,  4.68it/s]
# Running ran_indeg_strategy with 600 pivots: 100%|██████████| 20/20 [00:04<00:00,  4.40it/s]
# Running ran_indeg_strategy with 650 pivots: 100%|██████████| 20/20 [00:04<00:00,  4.12it/s]
# Running ran_indeg_strategy with 700 pivots: 100%|██████████| 20/20 [00:04<00:00,  4.15it/s]
# Running ran_indeg_strategy with 750 pivots: 100%|██████████| 20/20 [00:05<00:00,  3.46it/s]
# Running ran_indeg_strategy with 800 pivots: 100%|██████████| 20/20 [00:06<00:00,  3.28it/s]
# Running ran_indeg_strategy with 850 pivots: 100%|██████████| 20/20 [00:06<00:00,  3.10it/s]
# Running ran_indeg_strategy with 900 pivots: 100%|██████████| 20/20 [00:06<00:00,  2.98it/s]
# Running ran_indeg_strategy with 950 pivots: 100%|██████████| 20/20 [00:06<00:00,  3.10it/s]
# Running ran_indeg_strategy with 1000 pivots: 100%|██████████| 20/20 [00:07<00:00,  2.74it/s]
# Running ran_outdeg_strategy with 50 pivots: 100%|██████████| 20/20 [00:01<00:00, 18.44it/s]
# Running ran_outdeg_strategy with 100 pivots: 100%|██████████| 20/20 [00:01<00:00, 14.62it/s]
# Running ran_outdeg_strategy with 150 pivots: 100%|██████████| 20/20 [00:01<00:00, 13.44it/s]
# Running ran_outdeg_strategy with 200 pivots: 100%|██████████| 20/20 [00:01<00:00, 11.62it/s]
# Running ran_outdeg_strategy with 250 pivots: 100%|██████████| 20/20 [00:02<00:00,  9.67it/s]
# Running ran_outdeg_strategy with 300 pivots: 100%|██████████| 20/20 [00:02<00:00,  8.45it/s]
# Running ran_outdeg_strategy with 350 pivots: 100%|██████████| 20/20 [00:03<00:00,  6.59it/s]
# Running ran_outdeg_strategy with 400 pivots: 100%|██████████| 20/20 [00:03<00:00,  6.04it/s]
# Running ran_outdeg_strategy with 450 pivots: 100%|██████████| 20/20 [00:03<00:00,  5.91it/s]
# Running ran_outdeg_strategy with 500 pivots: 100%|██████████| 20/20 [00:03<00:00,  5.27it/s]
# Running ran_outdeg_strategy with 550 pivots: 100%|██████████| 20/20 [00:03<00:00,  5.09it/s]
# Running ran_outdeg_strategy with 600 pivots: 100%|██████████| 20/20 [00:04<00:00,  4.75it/s]
# Running ran_outdeg_strategy with 650 pivots: 100%|██████████| 20/20 [00:04<00:00,  4.46it/s]
# Running ran_outdeg_strategy with 700 pivots: 100%|██████████| 20/20 [00:04<00:00,  4.20it/s]
# Running ran_outdeg_strategy with 750 pivots: 100%|██████████| 20/20 [00:05<00:00,  3.87it/s]
# Running ran_outdeg_strategy with 800 pivots: 100%|██████████| 20/20 [00:05<00:00,  3.71it/s]
# Running ran_outdeg_strategy with 850 pivots: 100%|██████████| 20/20 [00:05<00:00,  3.53it/s]
# Running ran_outdeg_strategy with 900 pivots: 100%|██████████| 20/20 [00:05<00:00,  3.35it/s]
# Running ran_outdeg_strategy with 950 pivots: 100%|██████████| 20/20 [00:06<00:00,  3.16it/s]
# Running ran_outdeg_strategy with 1000 pivots: 100%|██████████| 20/20 [00:06<00:00,  3.03it/s]
# Running pagerank_pivot_selection with 50 pivots: 100%|██████████| 20/20 [00:00<00:00, 24.28it/s]
# Running pagerank_pivot_selection with 100 pivots: 100%|██████████| 20/20 [00:00<00:00, 20.55it/s]
# Running pagerank_pivot_selection with 150 pivots: 100%|██████████| 20/20 [00:01<00:00, 16.76it/s]
# Running pagerank_pivot_selection with 200 pivots: 100%|██████████| 20/20 [00:01<00:00, 14.18it/s]
# Running pagerank_pivot_selection with 250 pivots: 100%|██████████| 20/20 [00:01<00:00, 12.30it/s]
# Running pagerank_pivot_selection with 300 pivots: 100%|██████████| 20/20 [00:01<00:00, 10.67it/s]
# Running pagerank_pivot_selection with 350 pivots: 100%|██████████| 20/20 [00:02<00:00,  9.46it/s]
# Running pagerank_pivot_selection with 400 pivots: 100%|██████████| 20/20 [00:02<00:00,  8.20it/s]
# Running pagerank_pivot_selection with 450 pivots: 100%|██████████| 20/20 [00:02<00:00,  7.27it/s]
# Running pagerank_pivot_selection with 500 pivots: 100%|██████████| 20/20 [00:03<00:00,  5.94it/s]
# Running pagerank_pivot_selection with 550 pivots: 100%|██████████| 20/20 [00:03<00:00,  5.92it/s]
# Running pagerank_pivot_selection with 600 pivots: 100%|██████████| 20/20 [00:03<00:00,  5.67it/s]
# Running pagerank_pivot_selection with 650 pivots: 100%|██████████| 20/20 [00:04<00:00,  4.88it/s]
# Running pagerank_pivot_selection with 700 pivots: 100%|██████████| 20/20 [00:04<00:00,  4.85it/s]
# Running pagerank_pivot_selection with 750 pivots: 100%|██████████| 20/20 [00:04<00:00,  4.44it/s]
# Running pagerank_pivot_selection with 800 pivots: 100%|██████████| 20/20 [00:04<00:00,  4.14it/s]
# Running pagerank_pivot_selection with 850 pivots: 100%|██████████| 20/20 [00:05<00:00,  3.82it/s]
# Running pagerank_pivot_selection with 900 pivots: 100%|██████████| 20/20 [00:05<00:00,  3.60it/s]
# Running pagerank_pivot_selection with 950 pivots: 100%|██████████| 20/20 [00:05<00:00,  3.42it/s]
# Running pagerank_pivot_selection with 1000 pivots: 100%|██████████| 20/20 [00:06<00:00,  3.23it/s]
# Running mixed_strategy with 50 pivots: 100%|██████████| 20/20 [00:00<00:00, 22.15it/s]
# Running mixed_strategy with 100 pivots: 100%|██████████| 20/20 [00:01<00:00, 17.12it/s]
# Running mixed_strategy with 150 pivots: 100%|██████████| 20/20 [00:01<00:00, 14.50it/s]
# Running mixed_strategy with 200 pivots: 100%|██████████| 20/20 [00:01<00:00, 12.13it/s]
# Running mixed_strategy with 250 pivots: 100%|██████████| 20/20 [00:01<00:00, 10.50it/s]
# Running mixed_strategy with 300 pivots: 100%|██████████| 20/20 [00:02<00:00,  9.08it/s]
# Running mixed_strategy with 350 pivots: 100%|██████████| 20/20 [00:02<00:00,  8.16it/s]
# Running mixed_strategy with 400 pivots: 100%|██████████| 20/20 [00:02<00:00,  7.29it/s]
# Running mixed_strategy with 450 pivots: 100%|██████████| 20/20 [00:03<00:00,  6.62it/s]
# Running mixed_strategy with 500 pivots: 100%|██████████| 20/20 [00:03<00:00,  5.99it/s]
# Running mixed_strategy with 550 pivots: 100%|██████████| 20/20 [00:03<00:00,  5.58it/s]
# Running mixed_strategy with 600 pivots: 100%|██████████| 20/20 [00:03<00:00,  5.07it/s]
# Running mixed_strategy with 650 pivots: 100%|██████████| 20/20 [00:04<00:00,  4.79it/s]
# Running mixed_strategy with 700 pivots: 100%|██████████| 20/20 [00:04<00:00,  4.49it/s]
# Running mixed_strategy with 750 pivots: 100%|██████████| 20/20 [00:04<00:00,  4.15it/s]
# Running mixed_strategy with 800 pivots: 100%|██████████| 20/20 [00:05<00:00,  3.97it/s]
# Running mixed_strategy with 850 pivots: 100%|██████████| 20/20 [00:05<00:00,  3.80it/s]
# Running mixed_strategy with 900 pivots: 100%|██████████| 20/20 [00:05<00:00,  3.57it/s]
# Running mixed_strategy with 950 pivots: 100%|██████████| 20/20 [00:05<00:00,  3.36it/s]
# Running mixed_strategy with 1000 pivots: 100%|██████████| 20/20 [00:06<00:00,  3.25it/s]

# %%
print(results)
# Out:
# {'random_strategy': {50: {'average_euclidean_distance': 0.026582732475267358, 'average_inversion_number': 83053.45}, 100: {'average_euclidean_distance': 0.0187780182670545, 'average_inversion_number': 61277.9}, 150: {'average_euclidean_distance': 0.01490735154499541, 'average_inversion_number': 49456.2}, 200: {'average_euclidean_distance': 0.01276867968632443, 'average_inversion_number': 41218.3}, 250: {'average_euclidean_distance': 0.011157146880385096, 'average_inversion_number': 36880.05}, 300: {'average_euclidean_distance': 0.00983397873737008, 'average_inversion_number': 32664.1}, 350: {'average_euclidean_distance': 0.008625507886601502, 'average_inversion_number': 29209.6}, 400: {'average_euclidean_distance
# %%
import matplotlib.pyplot as plt 

plt.figure(figsize=(12, 8))
for strategy, data in results.items():
    x = list(data.keys())  # Number of pivots
    y = [metrics["average_euclidean_distance"] for metrics in data.values()]  # Extract Euclidean distance
    plt.plot(x, y, label=strategy)

plt.xlabel("Number of Pivots")
plt.ylabel("Average Euclidean Distance")
plt.title("Closeness in random graphs")
plt.legend()
plt.ylim(0, None)
plt.show()

# %%
import matplotlib.pyplot as plt 

plt.figure(figsize=(12, 8))
for strategy, data in results.items():
    x = list(data.keys())  # Number of pivots
    y = [metrics["average_inversion_number"] for metrics in data.values()]  # Extract Inversion number
    plt.plot(x, y, label=strategy)

plt.xlabel("Number of Pivots")
plt.ylabel("Average Inversion Number")
plt.title("Closeness in random graphs")
plt.legend()
plt.ylim(0, None)
plt.show()

# %% [markdown]
# ## Betweenness

# %% [markdown]
# 1. Select pivots according to the selection strategies
# 2. Access the shortest path from each pivot to all other nodes in the graph from the precomputed shortest paths
# 3. For each node v track how many shortest paths run through v
# 4. Sum the contributions of each node and normalize the aggregated betweenness centrality values by dividing by the total number of pivots

# %%
print(exact_betweenness)
print(len(all_shortest_paths))
# Out:
# {0: 0.003990440960335915, 1: 0.0014313088655315998, 2: 0.003703400443000284, 3: 0.0018294487108326699, 4: 0.0015131717075786008, 5: 0.0010824689271104063, 6: 0.000452426362318071, 7: 0.0014623397260528888, 8: 0.0019917573871242786, 9: 0.002821934443168092, 10: 0.0030292167994313396, 11: 0.002897246467307779, 12: 0.002656911404453547, 13: 0.0016994491952842389, 14: 0.0006523417470803045, 15: 0.001512402978318886, 16: 0.0027441740780628633, 17: 0.004268634887108192, 18: 0.002221653247911592, 19: 0.003942141926600422, 20: 0.004500186834817363, 21: 0.0019665949664041827, 22: 0.0019316582486202467, 23: 0.00439371051371484, 24: 0.001987922786736459, 25: 0.0034263676509962756, 26: 0.0015787650932412916, 27: 0.0015207480453560689, 28: 0.0020812923019972456, 29: 0.0014201254569623915, 30: 0.001981385731625823, 31: 0.0019740110642829435, 32: 0.0018470993873353123, 33: 0.0020170141555100446, 34: 0.000745701443092869, 35: 0.0016455215076650433, 36: 0.004422773656833873, 37: 0.0009363991314327737, 38: 0.0016581919014099875, 39: 0.003966831530462919, 40: 0.002361080825649385, 41: 0.002872358211821163, 42: 0.0012966509121976808, 43: 0.0021377882765728834, 44: 0.0014063472754444431, 45: 0.0013112397392639505, 46: 0.001949924971995586, 47: 0.0017583630481180803, 48: 0.0027040343446872567, 49: 0.0014410107954431481, 50: 0.004606598987328478, 51: 0.0019238817121588943, 52: 0.002437317204072498, 53: 0.0028320348189338354, 54: 0.002691426624511307, 55: 0.0030165302655847785, 56: 0.0035247750912903567, 57: 0.0013111984346324264, 58: 0.002592264060131348, 59: 0.0019550154584023157, 60: 0.0022880580076504115, 61: 0.0012722352226637648, 62: 0.00045897660403489577, 63: 0.0020506133188933667, 64: 0.0017384455231210113, 65: 0.0013355138341743541, 66: 0.0026628145390965034, 67: 0.001538450995056929, 68: 0.002183506164940102, 69: 0.003187274858525335, 70: 0.0023148587783275564, 71: 0.0014121606542129535, 72: 0.0026128119472130025, 73: 0.0024770219301992313, 74: 0.0020962611587381857, 75: 0.0024195823945675704, 76: 0.0035512
 91: 0.0023544088451563526, 92: 0.002141558967138123, 93: 0.0018175828353904145, 94: 0.0013506244756391287, 95: 0.003053481436195251, 96: 0.002065018372175379, 97: 0.0017506628674548858, 98: 0.0031092794935372275, 99: 0.00515099068752576, 100: 0.0012807982405837542, 101: 0.0015570457077353956, 102: 0.002763822709765282, 103: 0.002067999695989424, 104: 0.003494698079327358, 105: 0.003076070458691579, 106: 0.004738425666563108, 107: 0.0023263333050112115, 108: 0.003175670761959725, 109: 0.0013441983188514082, 110: 0.0027351845924886474, 111: 0.0024102915131973394, 112: 0.0022592475323999547, 113: 0.003722008721825926, 114: 0.0030351877339276183, 115: 0.002753734361447116, 116: 0.0019000735206501729, 117: 0.0009830963087761736, 118: 0.001959153525007351, 119: 0.0016810752942330255, 120: 0.0031472697135121385, 121: 0.003572094355969113, 122: 0.003141528518143598, 123: 0.0012330264083262577, 124: 0.002550345038661771, 125: 0.0011364792587093284, 126: 0.001403494695110718, 127: 0.003642841714365933, 128: 0.0011278522059290504, 129: 0.0008458032634833583, 130: 0.001846054513455819, 131: 0.004296620717716485, 132: 0.0018235868620851171, 133: 0.0021132949227341516, 134: 0.0010441947450050223, 135: 0.0042227923581817, 136: 0.0011917178297987845, 137: 0.005399578527256736, 138: 0.0022811727847021016, 139: 0.0024099707763077425, 140: 0.0016192055630765174, 141: 0.0017070270592899398, 142: 0.001690855858089152, 143: 0.0030225014179377477, 144: 0.0020230890837147084, 145: 0.0019436124300331698, 146: 0.0034185983463230515, 147: 0.0019802471063419297, 148: 0.0010278894 ...
# 0.04629157185852791

# %%
strategies = [random_strategy, ran_indeg_strategy, 
              ran_outdeg_strategy, pagerank_pivot_selection, mixed_strategy]

num_pivots_list = [int(len(G.nodes) / 20 * i) for i in range(1, 21)]
print(num_pivots_list)
# Out:
# [50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700, 750, 800, 850, 900, 950, 1000]

# %%
from tqdm import tqdm
import numpy as np

def run_experiment_betweenness(G, strategies, num_pivots_list, all_shortest_paths, exact_betweenness, runs=20):
    results = {}

    for strategy in strategies:
        results[strategy.__name__] = {}
        for num_pivots in num_pivots_list:
            euclidean_distances = []
            inversions = []

            for _ in tqdm(range(runs), desc=f"Running {strategy.__name__} with {num_pivots} pivots"):
                approximated_betweenness = run_strategy_betweenness(G, strategy, num_pivots, all_shortest_paths)

                eucl_dist = euclidean_distance(exact_betweenness, approximated_betweenness)
                inversion = compute_inversion_distance(exact_betweenness, approximated_betweenness)

                euclidean_distances.append(eucl_dist)
                inversions.append(inversion)

            avg_eucl_dist = np.mean(euclidean_distances)
            avg_inversion = np.mean(inversions)

            results[strategy.__name__][num_pivots] = {
                'euclidean_distance': avg_eucl_dist,
                'inversion_number': avg_inversion
            }

    return results


results_betweenness = run_experiment_betweenness(G, strategies, num_pivots_list, all_shortest_paths, exact_betweenness)
# Out:
# Running random_strategy with 50 pivots: 100%|██████████| 20/20 [00:01<00:00, 10.89it/s]
# Running random_strategy with 100 pivots: 100%|██████████| 20/20 [00:02<00:00,  6.74it/s]
# Running random_strategy with 150 pivots:  10%|█         | 2/20 [00:00<00:03,  4.91it/s]
# Running random_strategy with 150 pivots: 100%|██████████| 20/20 [00:04<00:00,  4
# Running ran_indeg_strategy with 850 pivots: 100%|██████████| 20/20 [00:19<00:00,  1.02it/s]
# Running ran_indeg_strategy with 900 pivots: 100%|██████████| 20/20 [00:20<00:00,  1.04s/it]
# Running ran_indeg_strategy with 950 pivots: 100%|██████████| 20/20 [00:21<00:00,  1.09s/it]
# Running ran_indeg_strategy with 1000 pivots: 100%|██████████| 20/20 [00:22<00:00,  1.15s/it]
# Running ran_outdeg_strategy with 50 pivots: 100%|██████████| 20/20 [00:01<00:00, 10.90it/s]
# Running ran_outdeg_strategy with 100 pivots: 100%|██████████| 20/20 [00:02<00:00,  6.81it/s]
# Running ran_outdeg_strategy with 150 pivots: 100%|██████████| 20/20 [00:04<00:00,  4.95it/s]
# Running ran_outdeg_strategy with 200 pivots: 100%|██████████| 20/20 [00:05<00:00,  3.89it/s]
# Running ran_outdeg_strategy with 250 pivots: 100%|██████████| 20/20 [00:06<00:00,  3.21it/s]
# Running ran_outdeg_strategy with 300 pivots: 100%|██████████| 20/20 [00:07<00:00,  2.72it/s]
# Running ran_outdeg_strategy with 350 pivots: 100%|██████████| 20/20 [00:08<00:00,  2.36it/s]
# Running ran_outdeg_strategy with 400 pivots: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s]
# Running ran_outdeg_strategy with 450 pivots: 100%|██████████| 20/20 [00:10<00:00,  1.87it/s]
# Running ran_outdeg_strategy with 500 pivots: 100%|██████████| 20/20 [00:11<00:00,  1.71it/s]
# Running ran_outdeg_strategy with 550 pivots: 100%|██████████| 20/20 [00:12<00:00,  1.55it/s]
# Running ran_outdeg_strategy with 600 pivots: 100%|██████████| 20/20 [00:14<00:00,  1.43it/s]
# Running ran_outdeg_strategy with 650 pivots: 100%|██████████| 20/20 [00:15<00:00,  1.32it/s]
# Running ran_outdeg_strategy with 700 pivots: 100%|██████████| 20/20 [00:16<00:00,  1.24it/s]
# Running ran_outdeg_strategy with 750 pivots: 100%|██████████| 20/20 [00:17<00:00,  1.15it/s]
# Running ran_outdeg_strategy with 800 pivots: 100%|██████████| 20/20 [00:18<00:00,  1.08it/s]
# Running ran_outdeg_strategy with 850 pivots: 100%|██████████| 20/20 [00:19<00:00,  1.02it/s]
# Running ran_outdeg_strategy with 900 pivots:  20%|██        | 4/20 [00:04<00:16,  1.05s/it]

# %%
import matplotlib.pyplot as plt 

plt.figure(figsize=(12, 8))
for strategy, data in results_betweenness.items():
    x = list(data.keys())  # Number of pivots
    y = [metrics["euclidean_distance"] for metrics in data.values()]  # Extract Euclidean distance
    plt.plot(x, y, label=strategy)

plt.xlabel("Number of Pivots")
plt.ylabel("Average Euclidean Distance")
plt.title("Betweenness in random graphs")
plt.legend()
plt.ylim(0, None)
plt.show()

# %%
import matplotlib.pyplot as plt 

plt.figure(figsize=(12, 8))
for strategy, data in results_betweenness.items():
    x = list(data.keys())  # Number of pivots
    y = [metrics["inversion_number"] for metrics in data.values()]  # Extract Inversion number
    plt.plot(x, y, label=strategy)

plt.xlabel("Number of Pivots")
plt.ylabel("Average Inversion Number")
plt.title("Closeness in random graphs")
plt.legend()
plt.ylim(0, None)
plt.show()
